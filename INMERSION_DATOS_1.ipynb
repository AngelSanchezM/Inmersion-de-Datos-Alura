# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles = pd.read_csv("/content/drive/MyDrive/Base de Datos/inmuebles_bogota.csv")
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = { "Baños":"Banos", "Área":"Area" }
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1798         Casa         Casa en venta en Zona Noroccidental             4
# 8999  Apartamento            Apartamento en venta en Cedritos             2
# 8880         Casa                Casa en venta en Teusaquillo             9
# 7457         Casa         Casa en venta en Rafael Uribe Uribe            13
# 2106  Apartamento      Apartamento en venta en Barrios Unidos             3
# 3175  Apartamento                Apartamento en venta en Suba             2
# 5373  Apartamento                Apartamento en venta en Bosa             3
# 132   Apartamento  Apartamento en venta en Zona Noroccidental             2
# 3328  Apartamento             Apartamento en venta en Kennedy             2
# 6664         Casa                   Casa en venta en Engativa            12
#
#       Banos  Area              Barrio                                 UPZ  \
# 1798      3  1182  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 8999      2    97            Cedritos                             Usaquén
# 8880      3   298         Teusaquillo                         Teusaquillo
# 7457      8   430  Rafael Uribe Uribe                       Los Alcázares
# 2106      4   230      Barrios Unidos                           Los Andes
# 3175      2    55                Suba                                Suba
# 5373      1    47                Bosa                        Bosa Central
# 132       2    51  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3328      2    54             Kennedy                     Kennedy Central
# 6664      4   454            Engativa                            Engativá
#
#                 Valor
# 1798  $ 1.344.332.000
# 8999    $ 487.000.000
# 8880    $ 958.000.000
# 7457    $ 800.000.000
# 2106  $ 1.100.000.000
# 3175    $ 240.000.000
# 5373    $ 125.000.000
# 132     $ 245.500.000
# 3328    $ 250.000.000
# 6664    $ 880.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[400]
# Out:
# Tipo                                           Apartamento
# Descripcion     Apartamento en venta en Zona Noroccidental
# Habitaciones                                             3
# Banos                                                    1
# Area                                                    60
# Barrio                                  Zona Noroccidental
# UPZ                     CHAPINERO: Pardo Rubio + Chapinero
# Valor                                        $ 167.500.000
# Name: 400, dtype: object

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:308]
# Out:
#             Tipo                              Descripcion  Habitaciones  \
# 300  Apartamento          Apartamento en venta en Kennedy             2
# 301  Apartamento      Apartamento en venta en Chico Norte             2
# 302  Apartamento          Apartamento en venta en Kennedy             3
# 303  Apartamento          Apartamento en venta en Kennedy             3
# 304  Apartamento         Apartamento en venta en Cedritos             4
# 305  Apartamento         Apartamento en venta en Cedritos             3
# 306  Apartamento             Apartamento en venta en Bosa             2
# 307  Apartamento  Apartamento en venta en Chico Reservado             3
#
#      Banos  Area           Barrio                                 UPZ  \
# 300      1    42          Kennedy                     Kennedy Central
# 301      2    95      Chico Norte  CHAPINERO: Chicó Lago + El Refugio
# 302      2    54          Kennedy                     Kennedy Central
# 303      2    67          Kennedy                     Kennedy Central
# 304      4   132         Cedritos                             Usaquén
# 305      3   108         Cedritos                             Usaquén
# 306      1    42             Bosa                        Bosa Central
# 307      3   166  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                Valor
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# 305    $ 503.000.000
# 306    $ 117.000.000
# 307  $ 1.300.000.000

# %%
type(inmuebles["Valor"][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 5690  Apartamento  Apartamento en venta en Cerros De Suba             3
# 6434  Apartamento   Apartamento en venta en Santa Barbara             3
# 370   Apartamento         Apartamento en venta en Mazuren             3
# 6346  Apartamento     Apartamento en venta en Teusaquillo             1
# 9427  Apartamento            Apartamento en venta en Niza             1
# ...           ...                                     ...           ...
# 2975  Apartamento        Apartamento en venta en Cedritos             2
# 6947  Apartamento   Apartamento en venta en La Estanzuela             3
# 1300  Apartamento   Apartamento en venta en Santa Barbara             3
# 7623         Casa        Casa en venta en Chico Reservado             2
# 2991  Apartamento        Apartamento en venta en Engativa             3
#
#       Banos  Area           Barrio                                    UPZ  \
# 5690      3   154   Cerros De Suba                                   Suba
# 6434      4   225    Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 370       3   109          Mazuren                               El Prado
# 6346      1    37      Teusaquillo                            Teusaquillo
# 9427      1    50             Niza                                   Niza
# ...     ...   ...              ...                                    ...
# 2975      2    86         Cedritos                                Usaquén
# 6947      1    46    La Estanzuela                              El Rincón
# 1300      3   114    Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 7623      2    88  Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 2991      2    70         Engativa                               Engativá
#
#                 Valor
# 5690    $ 830.000.000
# 6434  $ 1.150.000.000
# 370     $ 360.000.000
# 6346    $ 330.000.000
# 9427    $ 374.000.000
# ...               ...
# 2975    $ 520.000.000
# 6947    $ 140.000.000
# 1300    $ 690.000.000
# 7623    $ 700.000.000
# 2991    $ 298.500.000
#
# [100 rows x 8 columns]

# %%
(inmuebles.Barrio == "Chico Reservado")
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == "Chico Reservado"))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == "Chico Reservado")
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Desafio 1

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
inmuebles = pd.read_csv("/content/drive/MyDrive/Base de Datos/inmuebles_bogota.csv")
inmuebles.head()
columnas = { "Baños":"Banos", "Área":"Area" }
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              Tipo                             Descripcion  Habitaciones  \
# 7650  Apartamento        Apartamento en venta en Fontibón             2
# 7716  Apartamento        Apartamento en venta en Fontibón             3
# 3590  Apartamento  Apartamento en venta en Ciudad Bolívar             2
# 4381         Casa                   Casa en venta en Usme             2
# 8588  Apartamento            Apartamento en venta en Bosa             3
# 4622  Apartamento       Apartamento en venta en Chapinero             2
# 2110  Apartamento  Apartamento en venta en Barrios Unidos             3
# 7580         Casa          Casa en venta en Santa Barbara             4
# 4205  Apartamento         Apartamento en venta en Palermo             2
# 472   Apartamento        Apartamento en venta en Cedritos             2
#
#       Banos  Area          Barrio  \
# 7650      1    49        Fontibón
# 7716      2    55        Fontibón
# 3590      1    38  Ciudad Bolívar
# 4381      2    43            Usme
# 8588      1    42            Bosa
# 4622      2    61       Chapinero
# 2110      2    63  Barrios Unidos
# 7580      5   296   Santa Barbara
# 4205      2    77         Palermo
# 472       2    64        Cedritos
#
#                                                     UPZ            Valor
# 7650                                           Fontibón    $ 170.000.000
# 7716                                           Fontibón    $ 160.000.000
# 3590  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 165.000.000
# 4381                  USME: Alfonso López + Ciudad Usme     $ 85.000.000
# 8588                                       Bosa Central    $ 140.000.000
# 4622                 CHAPINERO: Pardo Rubio + Chapinero    $ 335.000.000
# 2110                                          Los Andes    $ 230.000.000
# 7580              USAQUÉN: Country Club + Santa Bárbara  $ 1.350.000.000
# 4205                                           Galerías    $ 462.000.000
# 472                                             Usaquén    $ 277.000.000

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
columnas = { "Baños":"Banos", "Área":"Area" }
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 3047         Casa                 Casa en venta en Kennedy             6
# 1716  Apartamento        Apartamento en venta en Pasadena              2
# 5478  Apartamento         Apartamento en venta en La Salle             1
# 1852         Casa                    Casa en venta en Suba             4
# 5908  Apartamento          Apartamento en venta en Usaquén             3
# 595          Casa                 Casa en venta en Usaquén             2
# 1542  Apartamento      Apartamento en venta en Los Rosales             3
# 1117  Apartamento          Apartamento en venta en Usaquén             1
# 8210  Apartamento      Apartamento en venta en Teusaquillo             4
# 3396  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 3047      4   288          Kennedy                     Kennedy Central
# 1716      3   109        Pasadena                                  NaN
# 5478      1    37         La Salle  CHAPINERO: Pardo Rubio + Chapinero
# 1852      3   340             Suba                                Suba
# 5908      2    79          Usaquén                             Usaquén
# 595       3   158          Usaquén                             Usaquén
# 1542      3   112      Los Rosales  CHAPINERO: Chicó Lago + El Refugio
# 1117      2    66          Usaquén                             Usaquén
# 8210      2   130      Teusaquillo                         Teusaquillo
# 3396      4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 3047    $ 382.000.000
# 1716    $ 699.000.000
# 5478    $ 220.000.000
# 1852  $ 1.600.000.000
# 5908    $ 300.000.000
# 595     $ 770.000.000
# 1542    $ 650.000.000
# 1117    $ 495.000.000
# 8210  $ 1.120.000.000
# 3396    $ 900.000.000

# %%
inmuebles.groupby("Barrio")["Area"].mean()
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
inmuebles_barrio_area = inmuebles.groupby("Barrio")["Area"].mean()
inmuebles_barrio_area.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles_barrio_area.plot.barh()
# Out:
# <Axes: ylabel='Barrio'>

# %%
inmuebles_barrio_area.head(10).sort_values(ascending=True).plot.barh()
# Out:
# <Axes: ylabel='Barrio'>

# %% [markdown]
# Tarea 2: Consultar otros datos estadisticos: Conteo, Mediana, Valores minimo y maximo.

# %%
# Aqui se puede apreciar la descripcion del dataset, he utilizdo la herramienta de .round() para redondear los decimales
inmuebles.describe().round(3)
# Out:
#        Habitaciones     Banos        Area
# count      9520.000  9520.000    9520.000
# mean          3.072     2.448     146.665
# std           2.050     1.255    1731.380
# min           1.000     0.000       2.000
# 25%           2.000     2.000      57.000
# 50%           3.000     2.000      80.000
# 75%           3.000     3.000     135.000
# max         110.000     9.000  166243.000

# %%
# Barrio con maximo de valores Habitacion, Baños, Area, Valor
inmuebles[["Habitaciones","Banos","Area","Valor"]].max()
# Out:
# Habitaciones              110
# Banos                       9
# Area                   166243
# Valor           $ 999.000.000
# dtype: object

# %%
# Barrio con minimo de valores Habitacion, Baños, Area, Valor
inmuebles[["Habitaciones","Banos","Area","Valor"]].min()
# Out:
# Habitaciones                  1
# Banos                         0
# Area                          2
# Valor           $ 1.000.000.000
# dtype: object
